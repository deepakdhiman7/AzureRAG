# %% [markdown]
# # RAG with Azure Blogstorage

# %%
import os
from dotenv import load_dotenv
from langchain_openai.chat_models.azure import AzureChatOpenAI

# %%
load_dotenv()
# Out:
# True

# %%
# Common configuration for AzureChatOpenAI
llm = AzureChatOpenAI(
    azure_deployment=os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT"),
    api_version="2024-12-01-preview",  # Or another valid version
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    temperature=0,
    max_tokens=500
)

# %%
response = llm.invoke("what is  TB-PRACTECAL?")

# %%
response
# Out:
# AIMessage(content='TB-PRACTECAL is a clinical trial focused on developing shorter, safer, and more effective treatment regimens for multidrug-resistant tuberculosis (MDR-TB). It is led by Médecins Sans Frontières (MSF), also known as Doctors Without Borders, in collaboration with various research institutions and organizations. The trial aims to address the challenges posed by MDR-TB, which is resistant to the two most powerful first-line TB drugs, rifampicin and isoniazid.\n\nThe TB-PRACTECAL trial tested new combinations of oral drugs to replace the lengthy and often toxic standard MDR-TB treatment regimens, which typically involve injectable drugs and can last up to 18–24 months. The trial focused on shorter regimens (around six months) using newer TB drugs such as bedaquiline, pretomanid, and linezolid, combined with other oral medications.\n\nIn 2022, TB-PRACTECAL demonstrated promising results, showing that the shorter, all-oral regimens were highly effective and had fewer side effects compared to traditional treatments. This marked a significant step forward in improving MDR-TB treatment outcomes and reducing the burden on patients.\n\nThe findings from TB-PRACTECAL are expected to influence global TB treatment guidelines and provide hope for better management of MDR-TB, which remains a major public health challenge worldwide.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 277, 'prompt_tokens': 17, 'total_tokens': 294, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-11-20', 'system_fingerprint': 'fp_b54fe76834', 'id': 'chatcmpl-CxuNGAK5UrQZxaL7fpO5rNUDmVnOd', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019bbc80-5b4f-7f90-b481-405947b68e02-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 277, 'total_tokens': 294, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
